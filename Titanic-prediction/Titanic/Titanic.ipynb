# %%
# 2. 只选2-3个最简单的特征（不要想复杂！）
# 性别和票价最容易影响生存率
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
test['Sex'] = test['Sex'].map({'male': 0, 'female': 1})

# 填充缺失值（用最简单的均值）
train['Fare'].fillna(train['Fare'].mean(),inplace=True)
test['Fare'].fillna(test['Fare'].mean(),inplace=True)

# 3. 准备数据
features = ['Sex', 'Fare']  # 只选这两个！
X_train = train[features]
y_train = train['Survived']
X_test = test[features]

# 4. 用最简单的模型
model = LogisticRegression()
model.fit(X_train, y_train)

# 5. 预测和提交
predictions = model.predict(X_test)
output = pd.DataFrame({'PassengerId': test['PassengerId'], 'Survived': predictions})
output.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 2. 只选2-3个最简单的特征（不要想复杂！）
#       2 # 性别和票价最容易影响生存率
# ----> 3 train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
#       4 test['Sex'] = test['Sex'].map({'male': 0, 'female': 1})
#       6 # 填充缺失值（用最简单的均值）
#
# NameError: name 'train' is not defined

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# 1. 加载数据（最基础的操作，你肯定会的！）
train = pd.read_csv('/Users/caierchang/Downloads/train.csv')
test = pd.read_csv('/Users/caierchang/Downloads/test.csv')
